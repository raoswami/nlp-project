# %%
#this project abouut NLP
'''
Aim:- Find the given participant certificate file name with given 
participant name from available certificates in given path  '''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
 
import cv2
import pytesseract
import PIL

# %%
img_cv=cv2.imread('./Participation Certificates/110.jpg')

# %%
img_cv=cv2.imread('sample.jpg')

# %%
cv2.imshow("Business Card ",img_cv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import pytesseract
text_from_image = pytesseract.image_to_string(img_cv)
print(text_from_image)
# Out:
# ellis MOBILE SOLUTION
#
# sessories
#
# A
#
# HUAWEl
#
# OEE
#
# NO

# %%
# import OS module
import os
# Get the list of all files and directories
path = "./Participation Certificates"
dir_list = os.listdir(path)

print("Files and directories in '", path, "' :")

# prints all files
print(dir_list)
# Out:
# Files and directories in ' ./Participation Certificates ' :
# ...

# %%
import spacy
from spacy.matcher import PhraseMatcher
# Out:
# KANTE MALLIKARJUN RAO

# %%
# import OS module
import os
import PIL
import pytesseract
# This is my path
path = "./Participation Certificates"
# to store files in a list
list = []

# dirs=directories
for (root, dirs, file) in os.walk(path):
    for f in file:
        file_path =f"{path}/{f}"
       # print(file_path)
    
        img_cv=PIL.Image.open(file_path)
        #text_from_image = pytesseract.image_to_string(img_cv)
        #print(file_path)
        #print(text_from_image)
        #name=re.findall(r'Mr./Ms.(.*)', chat)
        name=re.findall(r'Mr./Ms.(.*)', pytesseract.image_to_string(img_cv))
        print(file_path)
        if name=='KANTE MALLIKARJUNA RAO':
            print(name,file_path)
# Out:
# ./Participation Certificates/1.jpg
# ./Participation Certificates/110.jpg
# ./Participation Certificates/1100.jpg
# ./Participation Certificates/1101.jpg
# ./Participation Certificates/1102.jpg
# ./Participation Certificates/1103.jpg
# ./Participation Certificates/1104.jpg
# ./Participation Certificates/1105.jpg
# ./Participation Certificates/1106.jpg
# ./Participation Certificates/1107.jpg
# ./Participation Certificates/1108.jpg
# ./Participation Certificates/1109.jpg
# ./Participation Certificates/111.jpg
# ./Participation Certificates/1110.jpg
# ./Participation Certificates/1111.jpg
# ./Participation Certificates/1112.jpg
# ./Participation Certificates/1113.jpg
# ./Participation Certificates/1114.jpg
# ./Participation Certificates/1115.jpg
# ./Participation Certificates/1116.jpg
# ./Participation Certificates/1117.jpg
# ./Participation Certificates/1118.jpg
# ./Participation Certificates/1119.jpg
# ./Participation Certificates/112.jpg
# ./Participation Certificates/1120.jpg
# ...

# %%
##img_cv=cv2.imread(f)
        img_cv=PIL.Image.open(f)
        text_from_image = pytesseract.image_to_string(img_cv)
        print(text_from_image)

# %%
import re
chat='''
This is to certify that Mr./Ms. VEERABHADRESHWAR PATIL of Basavakalyan Engineering College has participated in One Week'''
name=re.findall(r'Mr./Ms.(.*)', chat)
print(name)
# Out:
# [' VEERABHADRESHWAR PATIL of Basavakalyan Engineering College has participated in One Week']
